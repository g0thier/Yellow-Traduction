# %%
# --- Cellule 1 : Dépendances (à exécuter une seule fois) ---
# !pip -q install "pymupdf>=1.24.9" "transformers>=4.43" "sentencepiece>=0.1.99" "accelerate>=0.33" bitsandbytes sacremoses -U

# %%
SOURCE_PDF = "/Users/gauthier/Documents/Travail/Projets/IFG/TASK HUB/Le cadre théorique/04 Sources essentielles de TASK™/9789240074323-eng.pdf"

# %%
from transformers import MarianTokenizer, MarianMTModel
MODEL_NAME = "Helsinki-NLP/opus-mt-en-fr"
MAX_NEW_TOKENS = 512                           # limite sortie par ligne
BATCH_SIZE = 16                                # taille lot traduction
DEVICE = "cpu"


tokenizer  = MarianTokenizer.from_pretrained(MODEL_NAME)
model  = MarianMTModel.from_pretrained(MODEL_NAME).to(DEVICE).eval()

# %%
import fitz  # PyMuPDF

doc = fitz.open(SOURCE_PDF)

# Extraction des blocs de texte
pages_text = []
for page in doc:
    blocks = page.get_text("blocks")  # [(x0,y0,x1,y1,"texte",bloc_num,...)]
    page_blocks = []
    for b in blocks:
        text = b[4].strip()
        if len(text) >= 4:  # on ignore les bouts trop courts
            page_blocks.append((b[:4], text))  # coordonnées + texte
    pages_text.append(page_blocks)

print("Exemple de blocs :", pages_text[0][:3])
# Out:
# Exemple de blocs : [((215.73899841308594, 773.1566772460938, 253.12347412109375, 799.91845703125), 'HEALTH\nFOR ALL'), ((185.19700622558594, 266.8390197753906, 401.7681579589844, 468.8710021972656), 'World \nHealth \nStatistics \n2023'), ((336.1419982910156, 563.7219848632812, 551.9020385742188, 687.9960327148438), 'Monitoring \nhealth for the \nSDGs\nSustainable Development Goals')]

# %%
def translate_texts(texts):
    inputs = tokenizer(texts, return_tensors="pt", padding=True, truncation=True).to(DEVICE)
    translated = model.generate(**inputs, max_new_tokens=MAX_NEW_TOKENS)
    return [tokenizer.decode(t, skip_special_tokens=True) for t in translated]

translated_pages = []
for page_idx, page_blocks in enumerate(pages_text, start=1):
    print(f"\n=== Traitement de la page {page_idx}/{len(pages_text)} ===")
    
    texts = [t for _, t in page_blocks]
    translations = []
    
    for i in range(0, len(texts), BATCH_SIZE):
        batch = texts[i:i+BATCH_SIZE]
        print(f"  - Traduction des blocks {i+1} à {min(i+BATCH_SIZE, len(texts))} sur {len(texts)}")
        
        batch_translations = translate_texts(batch)
        translations.extend(batch_translations)
    
    page_translated = [(coords, trans) for (coords, _), trans in zip(page_blocks, translations)]
    translated_pages.append(page_translated)
    
    print(f"  ✅ Page {page_idx} terminée ({len(page_blocks)} blocks traduits)")

print("\nExemple traduction première page :", translated_pages[0][:3])
# Out:
# === Traitement de la page 1/136 ===
#   - Traduction des blocks 1 à 3 sur 3
#   ✅ Page 1 terminée (3 blocks traduits)
#
# === Traitement de la page 2/136 ===
#   ✅ Page 2 terminée (0 blocks traduits)
#
# === Traitement de la page 3/136 ===
#   - Traduction des blocks 1 à 3 sur 3
#   ✅ Page 3 terminée (3 blocks traduits)
#
# === Traitement de la page 4/136 ===
#   - Traduction des blocks 1 à 16 sur 16
#   ✅ Page 4 terminée (16 blocks traduits)
#
# === Traitement de la page 5/136 ===
#   - Traduction des blocks 1 à 16 sur 24
#   - Traduction des blocks 17 à 24 sur 24
#   ✅ Page 5 terminée (24 blocks traduits)
#
# === Traitement de la page 6/136 ===
#   ✅ Page 6 terminée (0 blocks traduits)
#
# === Traitement de la page 7/136 ===
#   - Traduction des blocks 1 à 9 sur 9
#   ✅ Page 7 terminée (9 blocks traduits)
#
# === Traitement de la page 8/136 ===
#   - Traduction des blocks 1 à 16 sur 56
#   - Traduction des blocks 17 à 32 sur 56
#   - Traduction des blocks 33 à 48 sur 56
#   - Traduction des blocks 49 à 56 sur 56
#   ✅ Page 8 terminée (56 blocks traduits)
#
# === Traitement de la page 9/136 ===
#   - Traduction des blocks 1 à 6 sur 6
#   ✅ Page 9 terminée (6 blocks traduits)
#
# === Traitement de la page 10/136 ===
#   - Traduction des blocks 1 à 10 sur 10
#   ✅ Page 10 terminée (10 blocks traduits)
#
# === Traitement de la page 11/136 ===
#   - Traduction des blocks 1 à 2 sur 2
#   ✅ Page 11 terminée (2 blocks traduits)
#
# === Traitement de la page 12/136 ===
#   ✅ Page 12 terminée (0 blocks traduits)
#
# === Traitement de la page 13/136 ===
#   - Traduction des blocks 1 à 1 sur 1
#   ✅ Page 13 terminée (1 blocks traduits)
#
# === Traitement de la page 14/136 ===
#   - Traduction des blocks 1 à 16 sur 22
#   - Traduction des blocks 17 à 22 sur 22
#   ✅ Page 14 terminée (22 blocks traduits)
#
# === Traitement de la page 15/136 ===
#   - Traduction des blocks 1 à 16 sur 18
#   - Traduction des blocks 17 à 18 sur 18
#   ✅ Page 15 terminée (18 blocks traduits)
#
# === Traitement de la page 16/136 ===
#   - Traduction des blocks 1 à 16 sur 19
#   - Traduction des blocks 17 à 19 sur 19
#   ✅ Page 16 terminée (19 blocks traduits)
#
# === Traitement de la page 17/136 ===
#   - Traduction des blocks 1 à 16 sur 57
#   - Traduction des blocks 17 à 32 sur 57
#   - Traduction des blocks 33 à 48 sur 57
#   - Traduction des blocks 49 à 57 sur 57
#   ✅ Page 17 terminée (57 blocks traduits)
#
# === Traitement de la page 18/136 ===
#   - Traduction des blocks 1 à 9 sur 9
#   ✅ Page 18 terminée (9 blocks traduits)
#
# === Traitement de la page 19/136 ===
#   - Traduction des blocks 1 à 16 sur 46
#   - Traduction des blocks 17 à 32 sur 46
#   - Traduction des blocks 33 à 46 sur 46
#   ✅ Page 19 terminée (46 blocks traduits)
#
# === Traitement de la page 20/136 ===
#   - Traduction des blocks 1 à 16 sur 16
#   ✅ Page 20 terminée (16 blocks traduits)
#
# === Traitement de la page 21/136 ===
#   - Traduction des blocks 1 à 9 sur 9
#   ✅ Page 21 terminée (9 blocks traduits)
#
# === Traitement de la page 22/136 ===
#   - Traduction des blocks 1 à 14 sur 14
#   ✅ Page 22 terminée (14 blocks traduits)
#
# === Traitement de la page 23/136 ===
#   - Traduction des blocks 1 à 16 sur 62
#   - Traduction des blocks 17 à 32 sur 62
#   - Traduction des blocks 33 à 48 sur 62
#   - Traduction des blocks 49 à 62 sur 62
#   ✅ Page 23 terminée (62 blocks traduits)
#
# === Traitement de la page 24/136 ===
#   - Traduction des blocks 1 à 16 sur 21
#   - Traduction des blocks 17 à 21 sur 21
#   ✅ Page 24 terminée (21 blocks traduits)
#
# === Traitement de la page 25/136 ===
#   - Traduction des blocks 1 à 16 sur 54
#   - Traduction des blocks 17 à 32 sur 54
#   - Traduction des blocks 33 à 48 sur 54
#   - Traduction des blocks 49 à 54 sur 54
#   ✅ Page 25 terminée (54 blocks traduits)
#
# === Traitement de la page 26/136 ===
#   - Traduction des blocks 1 à 16 sur 22
#   - Traduction des blocks 17 à 22 sur 22
#   ✅ Page 26 terminée (22 blocks traduits)
#
# === Traitement de la page 27/136 ===
#   - Traduction des blocks 1 à 16 sur 41
#   - Traduction des blocks 17 à 32 sur 41
#   - Traduction des blocks 33 à 41 sur 41
#   ✅ Page 27 terminée (41 blocks traduits)
#
# === Traitement de la page 28/136 ===
#   - Traduction des blocks 1 à 8 sur 8
#   ✅ Page 28 terminée (8 blocks traduits)
#
# === Traitement de la page 29/136 ===
#   - Traduction des blocks 1 à 16 sur 24
#   - Traduction des blocks 17 à 24 sur 24
#   ✅ Page 29 terminée (24 blocks traduits)
#
# === Traitement de la page 30/136 ===
#   - Traduction des blocks 1 à 16 sur 18
#   - Traduction des blocks 17 à 18 sur 18
#   ✅ Page 30 terminée (18 blocks traduits)
#
# === Traitement de la page 31/136 ===
#   - Traduction des blocks 1 à 8 sur 8
#   ✅ Page 31 terminée (8 blocks traduits)
#
# === Traitement de la page 32/136 ===
#   - Traduction des blocks 1 à 13 sur 13
#   ✅ Page 32 terminée (13 blocks traduits)
#
# === Traitement de la page 33/136 ===
#   - Traduction des blocks 1 à 16 sur 16
#   ✅ Page 33 terminée (16 blocks traduits)
#
# === Traitement de la page 34/136 ===
#   - Traduction des blocks 1 à 15 sur 15
#   ✅ Page 34 terminée (15 blocks traduits)
#
# === Traitement de la page 35/136 ===
#   - Traduction des blocks 1 à 8 sur 8
#   ✅ Page 35 terminée (8 blocks traduits)
#
# === Traitement de la page 36/136 ===
#   - Traduction des blocks 1 à 12 sur 12
#   ✅ Page 36 terminée (12 blocks traduits)
#
# === Traitement de la page 37/136 ===
#   - Traduction des blocks 1 à 15 sur 15
#   ✅ Page 37 terminée (15 blocks traduits)
#
# === Traitement de la page 38/136 ===
#   - Traduction des blocks 1 à 12 sur 12
#   ✅ Page 38 terminée (12 blocks traduits)
#
# === Traitement de la page 39/136 ===
#   - Traduction des blocks 1 à 16 sur 20
#   - Traduction des blocks 17 à 20 sur 20
#   ✅ Page 39 terminée (20 blocks traduits)
#
# === Traitement de la page 40/136 ===
#   - Traduction des blocks 1 à 16 sur 16
#   ✅ Page 40 terminée (16 blocks traduits)
#
# === Traitement de la page 41/136 ===
#   - Traduction des blocks 1 à 16 sur 19
#   - Traduction des blocks 17 à 19 sur 19
#   ✅ Page 41 terminée (19 blocks traduits)
#
# === Traitement de la page 42/136 ===
#   - Traduction des blocks 1 à 16 sur 19
#   - Traduction des blocks 17 à 19 sur 19
#   ✅ Page 42 terminée (19 blocks traduits)
#
# === Traitement de la page 43/136 ===
#   - Traduction des blocks 1 à 16 sur 19
#   - Traduction des blocks 17 à 19 sur 19
#   ✅ Page 43 terminée (19 blocks traduits)
#
# === Traitement de la page 44/136 ===
#   ✅ Page 44 terminée (0 blocks traduits)
#
# === Traitement de la page 45/136 ===
#   - Traduction des blocks 1 à 1 sur 1
#   ✅ Page 45 terminée (1 blocks traduits)
#
# === Traitement de la page 46/136 ===
#   - Traduction des blocks 1 à 13 sur 13
#   ✅ Page 46 terminée (13 blocks traduits)
#
# === Traitement de la page 47/136 ===
#   - Traduction des blocks 1 à 16 sur 54
#   - Traduction des blocks 17 à 32 sur 54
#   - Traduction des blocks 33 à 48 sur 54
#   - Traduction des blocks 49 à 54 sur 54
#   ✅ Page 47 terminée (54 blocks traduits)
#
# === Traitement de la page 48/136 ===
#   - Traduction des blocks 1 à 16 sur 164
#   - Traduction des blocks 17 à 32 sur 164
#   - Traduction des blocks 33 à 48 sur 164
#   - Traduction des blocks 49 à 64 sur 164
#   - Traduction des blocks 65 à 80 sur 164
#   - Traduction des blocks 81 à 96 sur 164
#   - Traduction des blocks 97 à 112 sur 164
#   - Traduction des blocks 113 à 128 sur 164
#   - Traduction des blocks 129 à 144 sur 164
#   - Traduction des blocks 145 à 160 sur 164
#   - Traduction des blocks 161 à 164 sur 164
#   ✅ Page 48 terminée (164 blocks traduits)
#
# === Traitement de la page 49/136 ===
#   - Traduction des blocks 1 à 16 sur 30
#   - Traduction des blocks 17 à 30 sur 30
#   ✅ Page 49 terminée (30 blocks traduits)
#
# === Traitement de la page 50/136 ===
#   - Traduction des blocks 1 à 7 sur 7
#   ✅ Page 50 terminée (7 blocks traduits)
#
# === Traitement de la page 51/136 ===
#   - Traduction des blocks 1 à 16 sur 53
#   - Traduction des blocks 17 à 32 sur 53
#   - Traduction des blocks 33 à 48 sur 53
#   - Traduction des blocks 49 à 53 sur 53
#   ✅ Page 51 terminée (53 blocks traduits)
#
# === Traitement de la page 52/136 ===
#   - Traduction des blocks 1 à 12 sur 12
#   ✅ Page 52 terminée (12 blocks traduits)
#
# === Traitement de la page 53/136 ===
#   - Traduction des blocks 1 à 16 sur 20
#   - Traduction des blocks 17 à 20 sur 20
#   ✅ Page 53 terminée (20 blocks traduits)
#
# === Traitement de la page 54/136 ===
#   - Traduction des blocks 1 à 16 sur 21
#   - Traduction des blocks 17 à 21 sur 21
#   ✅ Page 54 terminée (21 blocks traduits)
#
# === Traitement de la page 55/136 ===
#   - Traduction des blocks 1 à 16 sur 36
#   - Traduction des blocks 17 à 32 sur 36
#   - Traduction des blocks 33 à 36 sur 36
#   ✅ Page 55 terminée (36 blocks traduits)
#
# === Traitement de la page 56/136 ===
#   - Traduction des blocks 1 à 5 sur 5
#   ✅ Page 56 terminée (5 blocks traduits)
#
# === Traitement de la page 57/136 ===
#   - Traduction des blocks 1 à 16 sur 37
#   - Traduction des blocks 17 à 32 sur 37
#   - Traduction des blocks 33 à 37 sur 37
#   ✅ Page 57 terminée (37 blocks traduits)
#
# === Traitement de la page 58/136 ===
#   - Traduction des blocks 1 à 16 sur 36
#   - Traduction des blocks 17 à 32 sur 36
#   - Traduction des blocks 33 à 36 sur 36
#   ✅ Page 58 terminée (36 blocks traduits)
#
# === Traitement de la page 59/136 ===
#   - Traduction des blocks 1 à 16 sur 36
#   - Traduction des blocks 17 à 32 sur 36
#   - Traduction des blocks 33 à 36 sur 36
#   ✅ Page 59 terminée (36 blocks traduits)
#
# === Traitement de la page 60/136 ===
#   - Traduction des blocks 1 à 16 sur 33
#   - Traduction des blocks 17 à 32 sur 33
#   - Traduction des blocks 33 à 33 sur 33
#   ✅ Page 60 terminée (33 blocks traduits)
#
# === Traitement de la page 61/136 ===
#   - Traduction des blocks 1 à 16 sur 20
#   - Traduction des blocks 17 à 20 sur 20
#   ✅ Page 61 terminée (20 blocks traduits)
#
# === Traitement de la page 62/136 ===
#   - Traduction des blocks 1 à 9 sur 9
#   ✅ Page 62 terminée (9 blocks traduits)
#
# === Traitement de la page 63/136 ===
#   - Traduction des blocks 1 à 16 sur 40
#   - Traduction des blocks 17 à 32 sur 40
#   - Traduction des blocks 33 à 40 sur 40
#   ✅ Page 63 terminée (40 blocks traduits)
#
# === Traitement de la page 64/136 ===
#   - Traduction des blocks 1 à 7 sur 7
#   ✅ Page 64 terminée (7 blocks traduits)
#
# === Traitement de la page 65/136 ===
#   - Traduction des blocks 1 à 12 sur 12
#   ✅ Page 65 terminée (12 blocks traduits)
#
# === Traitement de la page 66/136 ===
#   - Traduction des blocks 1 à 14 sur 14
#   ✅ Page 66 terminée (14 blocks traduits)
#
# === Traitement de la page 67/136 ===
#   - Traduction des blocks 1 à 6 sur 6
#   ✅ Page 67 terminée (6 blocks traduits)
#
# === Traitement de la page 68/136 ===
#   - Traduction des blocks 1 à 8 sur 8
#   ✅ Page 68 terminée (8 blocks traduits)
#
# === Traitement de la page 69/136 ===
#   - Traduction des blocks 1 à 16 sur 44
#   - Traduction des blocks 17 à 32 sur 44
#   - Traduction des blocks 33 à 44 sur 44
#   ✅ Page 69 terminée (44 blocks traduits)
#
# === Traitement de la page 70/136 ===
#   - Traduction des blocks 1 à 16 sur 28
#   - Traduction des blocks 17 à 28 sur 28
#   ✅ Page 70 terminée (28 blocks traduits)
#
# === Traitement de la page 71/136 ===
#   - Traduction des blocks 1 à 11 sur 11
#   ✅ Page 71 terminée (11 blocks traduits)
#
# === Traitement de la page 72/136 ===
#   - Traduction des blocks 1 à 16 sur 33
#   - Traduction des blocks 17 à 32 sur 33
#   - Traduction des blocks 33 à 33 sur 33
#   ✅ Page 72 terminée (33 blocks traduits)
#
# === Traitement de la page 73/136 ===
#   - Traduction des blocks 1 à 11 sur 11
#   ✅ Page 73 terminée (11 blocks traduits)
#
# === Traitement de la page 74/136 ===
#   - Traduction des blocks 1 à 16 sur 277
#   - Traduction des blocks 17 à 32 sur 277
#   - Traduction des blocks 33 à 48 sur 277
#   - Traduction des blocks 49 à 64 sur 277
#   - Traduction des blocks 65 à 80 sur 277
#   - Traduction des blocks 81 à 96 sur 277
#   - Traduction des blocks 97 à 112 sur 277
#   - Traduction des blocks 113 à 128 sur 277
#   - Traduction des blocks 129 à 144 sur 277
#   - Traduction des blocks 145 à 160 sur 277
#   - Traduction des blocks 161 à 176 sur 277
#   - Traduction des blocks 177 à 192 sur 277
#   - Traduction des blocks 193 à 208 sur 277
#   - Traduction des blocks 209 à 224 sur 277
#   - Traduction des blocks 225 à 240 sur 277
#   - Traduction des blocks 241 à 256 sur 277
#   - Traduction des blocks 257 à 272 sur 277
#   - Traduction des blocks 273 à 277 sur 277
#   ✅ Page 74 terminée (277 blocks traduits)
#
# === Traitement de la page 75/136 ===
#   - Traduction des blocks 1 à 16 sur 16
#   ✅ Page 75 terminée (16 blocks traduits)
#
# === Traitement de la page 76/136 ===
#   - Traduction des blocks 1 à 11 sur 11
#   ✅ Page 76 terminée (11 blocks traduits)
#
# === Traitement de la page 77/136 ===
#   - Traduction des blocks 1 à 16 sur 35
#   - Traduction des blocks 17 à 32 sur 35
#   - Traduction des blocks 33 à 35 sur 35
#   ✅ Page 77 terminée (35 blocks traduits)
#
# === Traitement de la page 78/136 ===
#   - Traduction des blocks 1 à 6 sur 6
#   ✅ Page 78 terminée (6 blocks traduits)
#
# === Traitement de la page 79/136 ===
#   - Traduction des blocks 1 à 16 sur 21
#   - Traduction des blocks 17 à 21 sur 21
#   ✅ Page 79 terminée (21 blocks traduits)
#
# === Traitement de la page 80/136 ===
#   - Traduction des blocks 1 à 16 sur 21
#   - Traduction des blocks 17 à 21 sur 21
#   ✅ Page 80 terminée (21 blocks traduits)
#
# === Traitement de la page 81/136 ===
#   - Traduction des blocks 1 à 16 sur 22
#   - Traduction des blocks 17 à 22 sur 22
#   ✅ Page 81 terminée (22 blocks traduits)
#
# === Traitement de la page 82/136 ===
#   - Traduction des blocks 1 à 16 sur 20
#   - Traduction des blocks 17 à 20 sur 20
#   ✅ Page 82 terminée (20 blocks traduits)
#
# === Traitement de la page 83/136 ===
#   - Traduction des blocks 1 à 1 sur 1
#   ✅ Page 83 terminée (1 blocks traduits)
#
# === Traitement de la page 84/136 ===
#   - Traduction des blocks 1 à 8 sur 8
#   ✅ Page 84 terminée (8 blocks traduits)
#
# === Traitement de la page 85/136 ===
#   - Traduction des blocks 1 à 16 sur 147
#   - Traduction des blocks 17 à 32 sur 147
#   - Traduction des blocks 33 à 48 sur 147
#   - Traduction des blocks 49 à 64 sur 147
#   - Traduction des blocks 65 à 80 sur 147
#   - Traduction des blocks 81 à 96 sur 147
#   - Traduction des blocks 97 à 112 sur 147
#   - Traduction des blocks 113 à 128 sur 147
#   - Traduction des blocks 129 à 144 sur 147
#   - Traduction des blocks 145 à 147 sur 147
#   ✅ Page 85 terminée (147 blocks traduits)
#
# === Traitement de la page 86/136 ===
#   - Traduction des blocks 1 à 5 sur 5
#   ✅ Page 86 terminée (5 blocks traduits)
#
# === Traitement de la page 87/136 ===
#   - Traduction des blocks 1 à 7 sur 7
#   ✅ Page 87 terminée (7 blocks traduits)
#
# === Traitement de la page 88/136 ===
#   - Traduction des blocks 1 à 16 sur 40
#   - Traduction des blocks 17 à 32 sur 40
#   - Traduction des blocks 33 à 40 sur 40
#   ✅ Page 88 terminée (40 blocks traduits)
#
# === Traitement de la page 89/136 ===
#   - Traduction des blocks 1 à 3 sur 3
#   ✅ Page 89 terminée (3 blocks traduits)
#
# === Traitement de la page 90/136 ===
#   - Traduction des blocks 1 à 8 sur 8
#   ✅ Page 90 terminée (8 blocks traduits)
#
# === Traitement de la page 91/136 ===
#   - Traduction des blocks 1 à 16 sur 97
#   - Traduction des blocks 17 à 32 sur 97
#   - Traduction des blocks 33 à 48 sur 97
#   - Traduction des blocks 49 à 64 sur 97
#   - Traduction des blocks 65 à 80 sur 97
#   - Traduction des blocks 81 à 96 sur 97
#   - Traduction des blocks 97 à 97 sur 97
#   ✅ Page 91 terminée (97 blocks traduits)
#
# === Traitement de la page 92/136 ===
#   - Traduction des blocks 1 à 6 sur 6
#   ✅ Page 92 terminée (6 blocks traduits)
#
# === Traitement de la page 93/136 ===
#   - Traduction des blocks 1 à 16 sur 16
#   ✅ Page 93 terminée (16 blocks traduits)
#
# === Traitement de la page 94/136 ===
#   ✅ Page 94 terminée (0 blocks traduits)
#
# === Traitement de la page 95/136 ===
#   - Traduction des blocks 1 à 11 sur 11
#   ✅ Page 95 terminée (11 blocks traduits)
#
# === Traitement de la page 96/136 ===
#   - Traduction des blocks 1 à 10 sur 10
#   ✅ Page 96 terminée (10 blocks traduits)
#
# === Traitement de la page 97/136 ===
#   - Traduction des blocks 1 à 16 sur 18
#   - Traduction des blocks 17 à 18 sur 18
#   ✅ Page 97 terminée (18 blocks traduits)
#
# === Traitement de la page 98/136 ===
#   - Traduction des blocks 1 à 8 sur 8
#   ✅ Page 98 terminée (8 blocks traduits)
#
# === Traitement de la page 99/136 ===
#   - Traduction des blocks 1 à 16 sur 17
#   - Traduction des blocks 17 à 17 sur 17
#   ✅ Page 99 terminée (17 blocks traduits)
#
# === Traitement de la page 100/136 ===
#   - Traduction des blocks 1 à 10 sur 10
#   ✅ Page 100 terminée (10 blocks traduits)
#
# === Traitement de la page 101/136 ===
#   - Traduction des blocks 1 à 16 sur 21
#   - Traduction des blocks 17 à 21 sur 21
#   ✅ Page 101 terminée (21 blocks traduits)
#
# === Traitement de la page 102/136 ===
#   - Traduction des blocks 1 à 14 sur 14
#   ✅ Page 102 terminée (14 blocks traduits)
#
# === Traitement de la page 103/136 ===
#   - Traduction des blocks 1 à 16 sur 23
# This is a friendly reminder - the current text generation call will exceed the model's predefined maximum length (512). Depending on the model, you may observe exceptions, performance degradation, or nothing at all.
#   - Traduction des blocks 17 à 23 sur 23
#   ✅ Page 103 terminée (23 blocks traduits)
#
# === Traitement de la page 104/136 ===
#   - Traduction des blocks 1 à 15 sur 15
#   ✅ Page 104 terminée (15 blocks traduits)
#
# === Traitement de la page 105/136 ===
#   - Traduction des blocks 1 à 16 sur 16
#   ✅ Page 105 terminée (16 blocks traduits)
#
# === Traitement de la page 106/136 ===
#   - Traduction des blocks 1 à 13 sur 13
#   ✅ Page 106 terminée (13 blocks traduits)
#
# === Traitement de la page 107/136 ===
#   - Traduction des blocks 1 à 15 sur 15
#   ✅ Page 107 terminée (15 blocks traduits)
#
# === Traitement de la page 108/136 ===
#   - Traduction des blocks 1 à 15 sur 15
#   ✅ Page 108 terminée (15 blocks traduits)
#
# === Traitement de la page 109/136 ===
#   - Traduction des blocks 1 à 16 sur 19
#   - Traduction des blocks 17 à 19 sur 19
#   ✅ Page 109 terminée (19 blocks traduits)
#
# === Traitement de la page 110/136 ===
#   - Traduction des blocks 1 à 16 sur 19
#   - Traduction des blocks 17 à 19 sur 19
#   ✅ Page 110 terminée (19 blocks traduits)
#
# === Traitement de la page 111/136 ===
#   - Traduction des blocks 1 à 16 sur 21
#   - Traduction des blocks 17 à 21 sur 21
#   ✅ Page 111 terminée (21 blocks traduits)
#
# === Traitement de la page 112/136 ===
#   - Traduction des blocks 1 à 16 sur 22
#   - Traduction des blocks 17 à 22 sur 22
#   ✅ Page 112 terminée (22 blocks traduits)
#
# === Traitement de la page 113/136 ===
#   - Traduction des blocks 1 à 16 sur 17
#   - Traduction des blocks 17 à 17 sur 17
#   ✅ Page 113 terminée (17 blocks traduits)
#
# === Traitement de la page 114/136 ===
#   - Traduction des blocks 1 à 16 sur 18
#   - Traduction des blocks 17 à 18 sur 18
#   ✅ Page 114 terminée (18 blocks traduits)
#
# === Traitement de la page 115/136 ===
#   - Traduction des blocks 1 à 16 sur 16
#   ✅ Page 115 terminée (16 blocks traduits)
#
# === Traitement de la page 116/136 ===
#   - Traduction des blocks 1 à 16 sur 21
#   - Traduction des blocks 17 à 21 sur 21
#   ✅ Page 116 terminée (21 blocks traduits)
#
# === Traitement de la page 117/136 ===
#   - Traduction des blocks 1 à 16 sur 20
#   - Traduction des blocks 17 à 20 sur 20
#   ✅ Page 117 terminée (20 blocks traduits)
#
# === Traitement de la page 118/136 ===
#   - Traduction des blocks 1 à 16 sur 24
#   - Traduction des blocks 17 à 24 sur 24
#   ✅ Page 118 terminée (24 blocks traduits)
#
# === Traitement de la page 119/136 ===
#   - Traduction des blocks 1 à 16 sur 22
#   - Traduction des blocks 17 à 22 sur 22
#   ✅ Page 119 terminée (22 blocks traduits)
#
# === Traitement de la page 120/136 ===
#   - Traduction des blocks 1 à 16 sur 17
#   - Traduction des blocks 17 à 17 sur 17
#   ✅ Page 120 terminée (17 blocks traduits)
#
# === Traitement de la page 121/136 ===
#   - Traduction des blocks 1 à 16 sur 20
#   - Traduction des blocks 17 à 20 sur 20
#   ✅ Page 121 terminée (20 blocks traduits)
#
# === Traitement de la page 122/136 ===
#   - Traduction des blocks 1 à 15 sur 15
#   ✅ Page 122 terminée (15 blocks traduits)
#
# === Traitement de la page 123/136 ===
#   - Traduction des blocks 1 à 16 sur 19
#   - Traduction des blocks 17 à 19 sur 19
#   ✅ Page 123 terminée (19 blocks traduits)
#
# === Traitement de la page 124/136 ===
#   - Traduction des blocks 1 à 16 sur 17
#   - Traduction des blocks 17 à 17 sur 17
#   ✅ Page 124 terminée (17 blocks traduits)
#
# === Traitement de la page 125/136 ===
#   - Traduction des blocks 1 à 16 sur 23
#   - Traduction des blocks 17 à 23 sur 23
#   ✅ Page 125 terminée (23 blocks traduits)
#
# === Traitement de la page 126/136 ===
#   - Traduction des blocks 1 à 16 sur 19
#   - Traduction des blocks 17 à 19 sur 19
#   ✅ Page 126 terminée (19 blocks traduits)
#
# === Traitement de la page 127/136 ===
#   - Traduction des blocks 1 à 16 sur 23
#   - Traduction des blocks 17 à 23 sur 23
#   ✅ Page 127 terminée (23 blocks traduits)
#
# === Traitement de la page 128/136 ===
#   - Traduction des blocks 1 à 16 sur 17
#   - Traduction des blocks 17 à 17 sur 17
#   ✅ Page 128 terminée (17 blocks traduits)
#
# === Traitement de la page 129/136 ===
#   - Traduction des blocks 1 à 14 sur 14
#   ✅ Page 129 terminée (14 blocks traduits)
#
# === Traitement de la page 130/136 ===
#   - Traduction des blocks 1 à 16 sur 23
#   - Traduction des blocks 17 à 23 sur 23
#   ✅ Page 130 terminée (23 blocks traduits)
#
# === Traitement de la page 131/136 ===
#   - Traduction des blocks 1 à 15 sur 15
#   ✅ Page 131 terminée (15 blocks traduits)
#
# === Traitement de la page 132/136 ===
#   ✅ Page 132 terminée (0 blocks traduits)
#
# === Traitement de la page 133/136 ===
#   ✅ Page 133 terminée (0 blocks traduits)
#
# === Traitement de la page 134/136 ===
#   ✅ Page 134 terminée (0 blocks traduits)
#
# === Traitement de la page 135/136 ===
#   ✅ Page 135 terminée (0 blocks traduits)
#
# === Traitement de la page 136/136 ===
#   - Traduction des blocks 1 à 1 sur 1
#   ✅ Page 136 terminée (1 blocks traduits)
#
# Exemple traduction première page : [((215.73899841308594, 773.1566772460938, 253.12347412109375, 799.91845703125), 'SANTÉ POUR TOUS'), ((185.19700622558594, 266.8390197753906, 401.7681579589844, 468.8710021972656), 'Statistiques de la santé dans le monde 2023'), ((336.1419982910156, 563.7219848632812, 551.9020385742188, 687.9960327148438), 'Suivi de la santé pour les ODD Objectifs de développement durable')]

# %%
sizes = (
    list(range(100, 49, -10)) +
    list(range(50, 19, -5)) +
    list(range(20, 13, -1)) +
    [round(x, 1) for x in [14 - i*0.1 for i in range(int((14-4)/0.1)+1)]]
)

# %%
for page_index, page in enumerate(doc):
    blocks = translated_pages[page_index]
    for coords, text in blocks:
        rect = fitz.Rect(coords)

        # dessiner un rectangle jaune
        page.draw_rect(rect, color=(1, 1, 0), fill=(1, 1, 0), fill_opacity=0.9, overlay=True)

        # --- ajustement automatique ---
        # On part d'une taille max et on réduit jusqu'à ce que ça rentre
        index_size = 0
        font_size = sizes[index_size]

        while index_size < len(sizes)-1 :  # limite basse
            rc = page.insert_textbox(
                rect,
                text,
                fontsize=font_size,
                color=(0, 0, 0),
                align=3,
                render_mode=3  # "mesure seulement", sans dessiner
            )
            if rc >= 0:  # le texte tient dans le rectangle
                break
            index_size += 1
            font_size = sizes[index_size]

        # Insérer réellement avec la bonne taille
        page.insert_textbox(
            rect,
            text,
            fontsize=font_size,
            color=(0, 0, 0),
            align=3
        )

OUTPUT_PDF = f"{SOURCE_PDF}_FR.pdf"
doc.save(OUTPUT_PDF)
print("PDF traduit sauvegardé sous", OUTPUT_PDF)
# Out:
# PDF traduit sauvegardé sous /Users/gauthier/Documents/Travail/Projets/IFG/TASK HUB/Le cadre théorique/04 Sources essentielles de TASK™/9789240074323-eng.pdf_FR.pdf
